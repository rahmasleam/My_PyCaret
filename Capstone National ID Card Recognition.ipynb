# %%
import pytesseract
import cv2
import numpy
import matplotlib.pyplot as plt
import pandas as pd

# %%
pytesseract.pytesseract.tesseract_cmd = r"C:\\Program Files\\Tesseract-OCR\\tesseract.exe"

# %%
img = cv2.imread("E:\After Graduate\Electropi\Image\e.png")
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gray)

# %%
th, threshed = cv2.threshold(gray, 127, 255, cv2.THRESH_TRUNC)
plt.imshow(threshed)

# %%
text1 = pytesseract.image_to_data(threshed,output_type='data.frame')
text2 = pytesseract.image_to_string(threshed, lang="eng")
print(text2)
lines = text.groupby('block_num')['text'].apply(list)
conf = text.groupby(['block_num'])['conf'].mean()
# Out:
# PASS Proof of Age Card GIT ZENCARD
#
# - 19 Oct 2008 =
#
# E :
# 31 Aug 2025 =
# 5843 2166 1964 4815
#
# 19 Oct 2024 Under 16

# %%
n_boxes = len(text1['text'])
for i in range(n_boxes):
    if int(text1['conf'][i]) > 60:
        (x, y, w, h) = (text1['left'][i], text1['top'][i], text1['width'][i], text1['height'][i])
        img = cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 2)

# %%
plt.imshow(img)

# %%
# Split the text2 output into a list of lines
lines = text2.split("\n")

# Create a Pandas DataFrame from the list of lines
df = pd.DataFrame(columns=["text"])
df["text"] = lines

# Print the DataFrame
print(df)
# Out:
#                                  text
# 0  PASS Proof of Age Card GIT ZENCARD
# 1
# 2                     - 19 Oct 2008 =
# 3
# 4                                 E :
# 5                       31 Aug 2025 =
# 6                 5843 2166 1964 4815
# 7
# 8                19 Oct 2024 Under 16
# 9
